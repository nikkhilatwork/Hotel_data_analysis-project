# %% [markdown]
# # Importing modulues

# %% [markdown]
# matplotlib & seaborn  is a python library that allows us to plot graphs and plots that helps us extract useful insights from data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline  
#used to display graph with single statement of code.

# %% [markdown]
# # Reading data

# %%
hotel = pd.read_csv('tips.csv')  #for reading the data

# %%
hotel
# Out:
#      total_bill   tip  gender smoker   day    time  team_size
# 0         16.99  1.01  Female     No   Sun  Dinner          2
# 1         10.34  1.66    Male     No   Sun  Dinner          3
# 2         21.01  3.50    Male     No   Sun  Dinner          3
# 3         23.68  3.31    Male     No   Sun  Dinner          2
# 4         24.59  3.61  Female     No   Sun  Dinner          4
# ..          ...   ...     ...    ...   ...     ...        ...
# 239       29.03  5.92    Male     No   Sat  Dinner          3
# 240       27.18  2.00  Female    Yes   Sat  Dinner          2
# 241       22.67  2.00    Male    Yes   Sat  Dinner          2
# 242       17.82  1.75    Male     No   Sat  Dinner          2
# 243       18.78  3.00  Female     No  Thur  Dinner          2
#
# [244 rows x 7 columns]

# %%
hotel.isnull().sum()  # is used to check how many null values available or not in data.
# Out:
# total_bill    0
# tip           0
# gender        0
# smoker        0
# day           0
# time          0
# team_size     0
# dtype: int64

# %%
hotel.head()
# Out:
#    total_bill   tip  gender smoker  day    time  team_size
# 0       16.99  1.01  Female     No  Sun  Dinner          2
# 1       10.34  1.66    Male     No  Sun  Dinner          3
# 2       21.01  3.50    Male     No  Sun  Dinner          3
# 3       23.68  3.31    Male     No  Sun  Dinner          2
# 4       24.59  3.61  Female     No  Sun  Dinner          4

# %%
hotel.info()  # will display information of tips data set.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   gender      244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   team_size   244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
hotel['day'].unique()   # to display the unique days available in day.
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %%
hotel['day'].nunique()  # .nunique() used to display the size of day
# Out:
# 4

# %%
#want to analyze the total bill paid 
sns.distplot(hotel['total_bill'])
# Out:
# C:\Users\nikhi\AppData\Local\Temp\ipykernel_19032\1692631539.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(hotel['total_bill'])
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.displot(hotel['total_bill'], kde = False, bins=20)
# Out:
# C:\Users\nikhi\anaconda3Nikhil\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.jointplot('tips','total_bill')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 sns.jointplot('tips','total_bill')
#
# TypeError: jointplot() takes from 0 to 1 positional arguments but 2 were given

# %%
sns.pairplot(hotel)
# Out:
# C:\Users\nikhi\anaconda3Nikhil\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(hotel, hue='gender')
# Out:
# C:\Users\nikhi\anaconda3Nikhil\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.kdeplot(hotel['total_bill'])
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
hotel.head()
# Out:
#    total_bill   tip  gender smoker  day    time  team_size
# 0       16.99  1.01  Female     No  Sun  Dinner          2
# 1       10.34  1.66    Male     No  Sun  Dinner          3
# 2       21.01  3.50    Male     No  Sun  Dinner          3
# 3       23.68  3.31    Male     No  Sun  Dinner          2
# 4       24.59  3.61  Female     No  Sun  Dinner          4

# %%
sns.countplot(x = 'gender', data=hotel)
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
sns.countplot(x = 'smoker', data=hotel)
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
sns.countplot(x = 'day', data=hotel)
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.countplot(x = 'day',data=hotel, hue='gender')
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.countplot(x = 'time', data = hotel, hue='gender')
# Out:
# <Axes: xlabel='time', ylabel='count'>

# %%
sns.barplot(x = 'gender', y = 'total_bill', data=hotel)
# Out:
# <Axes: xlabel='gender', ylabel='total_bill'>

# %%
sns.barplot(x = 'tip', y = 'day', data = hotel)
# Out:
# <Axes: xlabel='tip', ylabel='day'>

# %%
sns.barplot(x = 'day', y='tip', data=hotel)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.violinplot(x='day', y = 'total_bill', data=hotel, hue='gender')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x='day',y='total_bill', data = hotel)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
hotel.head()
# Out:
#    total_bill   tip  gender smoker  day    time  team_size
# 0       16.99  1.01  Female     No  Sun  Dinner          2
# 1       10.34  1.66    Male     No  Sun  Dinner          3
# 2       21.01  3.50    Male     No  Sun  Dinner          3
# 3       23.68  3.31    Male     No  Sun  Dinner          2
# 4       24.59  3.61  Female     No  Sun  Dinner          4

# %%
# if we want to compare every numerical data type  with each other
sns.pairplot(hotel)
# Out:
# C:\Users\nikhi\anaconda3Nikhil\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
